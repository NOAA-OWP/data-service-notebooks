# %% [markdown]
#   ### Retrieving NWM forecast data from the API
#
# Similar to the streamflow metadata endpoints, the total water level metadata endpoints utilize the same select_bys and parameters.  The key difference is total water level forecasts are associated with NWS Location IDs (and not NWM Feature IDs) We need a way to retrieve the data from the API. To achieve this, we first import Python's `requests` library, which allows us to make HTTP requests. Additionally, we import the `pprint` function from the `pprint` library to make the output more readable. Finally, we define the API endpoint we'll be interacting with, setting `API_ENDPOINT` to `https://api.water.noaa.gov/nwm/`. Here's how you can do it:
#
# ```python
# # start by importing the requests library
# import requests
# # import the pprint library to make the output more readable
# from pprint import pprint
# # define the api-endpoint
# API_ENDPOINT = "https://api.staging.water.noaa.gov/nwm"
# ```
#
# **Please change the endpoint to match the server you are interacting with.**
#
# From here  you will only need to set the uri, fetch the data, and print the results.  Here is a template for the code:
#
# ```python
# # set the uri
# uri = "/v1/total_water_level/configurations"
# # fetch the data
# r = requests.get(API_ENDPOINT + uri)
# # print the results
# pprint(r.json())
# ```

# %% [markdown]
#   ## Retrieving all NWM total water level forecast configurations from the API

# %% [markdown]
# ### Total Water Level configurations endpoint

# %% [markdown]
# Use this endpoint to inspect and filter National Water Model (NWM) total water level forecast configurations:
#
# * **Retrieve All Configurations:** Fetch the complete list of available NWM total water level forecast configurations.
# * **Filter Reaches by Configuration:** Pass a specific configuration to return all NWS gauges associated with it.

# %%
# start by importing the requests library
import requests
# import the pprint library to make the output more readable
from pprint import pprint
# define the api-endpoint
API_ENDPOINT = "https://api.staging.water.noaa.gov/nwm"

# %%
# create a total water level configurations request
uri = API_ENDPOINT + "/v1/total_water_level/configurations"

print(f'Retrieving total water level configurations from {uri} ...')
# get the response
response = requests.request("GET", uri)
# print the response
pprint(response.json())
# Out:
# Retrieving total water level configurations from https://api.staging.water.noaa.gov/nwm/v1/total_water_level/configurations ...
# {'configurations': ['short_range',
#                     'medium_range',
#                     'medium_range_blend',
#                     'analysis_assim',
#                     'analysis_assim_extend',
#                     'short_range_psurge',
#                     'medium_range_psurge',
#                     'medium_range_blend_psurge']}

# %%
# create a specific configuration request and retrieve the NWS location IDs for that configuration
uri = API_ENDPOINT + "/v1/total_water_level/configurations/short_range"
print(f'Retrieving all NWS gauges for a given configurations')

# get the response
response = requests.request("GET", uri)
# print the response
pprint(response.json())  # print the NWS location IDs)
# Out:
# Retrieving all NWS gauges for a given configurations
# {'nws_location_ids': ['AAMC1',
#                       'ABOP4',
#                       'ABRW1',
#                       'ABSN4',
#                       'ACFS1',
#                       'ACYN4',
#                       'AGQC1',
#                       'ALBN6',
#                       'ALCN4',
#                       'ALIN7',
#                       'ALWH1',
#                       'AMEM3',
#                       'AMRL1',
#                       'ANAD2',
#                       'ANAH1',
#                       'ANPT2',
#                       'ANVC1',
#                       'APAM2',
#                       'APCF1',
#                       'AQCV2',
#                       'ARIW1',
#                       'ARRM1',
#                       'ASCN4',
#                       'ASPS1',
#                       'ASTF1',
#                       'ASTO3',
#                       'ATLN4',
#                       'AVLN4',
#                       'AVNN7',
#                       'AVON7',
#                       'AWAC1',
#                       'AWRT2',
#                       'AXTV2',
#                       'AYCT2',
#                       'BAHM1',
#                       'BASN4',
#                       'BATN6',
#                       'BCSL1',
#                       'BCUF1',
#                       'BDAL1',
#                       'BDHV2',
#                       'BDPM2',
#                       'BDRN4',
#                       'BDSP1',
#                       'BDZC1',
#                       'BERN7',
#                       'BFBT2',
#                       'BFCS1',
#                       'BFTN7',
#                       'BGCV2',
#                       'BGLN4',
#                       'BGNN6',
#                       'BGYF1',
#                       'BHBM3',
#                       'BIDM1',
#                       'BISM2',
#                       'BKBF1',
#                       'BKNV2',
#                       'BKTL1',
#                       'BLDM2',
#                       'BLHN7',
#                       'BLIN7',
#                       'BLMN4',
#                       'BLRL1',
#                       'BLTM2',
#                       'BMTW1',
#                       'BOGN7',
#                       'BOWD1',
#                       'BPPD2',
#                       'BPPL1',
#                       'BQTM2',
#                       'BRHC3',
#                       'BRJF1',
#                       'BRND1',
#                       'BRNG1',
#                       'BRZT2',
#                       'BSRL1',
#                       'BSRN4',
#                       'BTBM1',
#                       'BTRL1',
#                       'BUCS1',
#                       'BVVN4',
#                       'BYSA1',
#                       'BZBM3',
#                       'BZST2',
#                       'CAMM1',
#                       'CAMM2',
#                       'CAPL1',
#                       'CAPN4',
#                       'CARL1',
#                       'CASM1',
#                       'CBBV2',
#                       'CBRN7',
#                       'CCHV2',
#                       'CCJF1',
#                       'CDDM1',
#                       'CECC1',
#                       'CHAO3',
#                       'CHBV2',
#                       'CHCM2',
#                       'CHDO3',
#                       'CHIV2',
#                       'CHMF1',
#                       'CHTM3',
#                       'CHTS1',
#                       'CHTT2',
#                       'CHWF1',
#                       'CHYW1',
#                       'CIBL1',
#                       'CIKA1',
#                       'CKBF1',
#                       'CKYF1',
#                       'CLCT2',
#                       'CLIC3',
#                       'CNMF1',
#                       'COLN7',
#                       'COVM2',
#                       'CPCS1',
#                       'CPEM1',
#                       'CPFS1',
#                       'CPMV2',
#                       'CPNT2',
#                       'CPTM2',
#                       'CPTR1',
#                       'CPTT2',
#                       'CPTW1',
#                       'CRSM2',
#                       'CSAG1',
#                       'CTIN7',
#                       'CTMF1',
#                       'CTNP4',
#                       'CWBF1',
#                       'CWOL1',
#                       'CYTF1',
#                       'DACL1',
#                       'DAMM1',
#                       'DCDF1',
#                       'DCWM1',
#                       'DELD1',
#                       'DGIF1',
#                       'DIBM6',
#                       'DICT2',
#                       'DKBN7',
#                       'DMSF1',
#                       'DNSF1',
#                       'DONL1',
#                       'DORP4',
#                       'DPBF1',
#                       'DPBO3',
#                       'DUCF1',
#                       'DUKN7',
#                       'DWMW1',
#                       'DYTT2',
#                       'EBEF1',
#                       'EBSW1',
#                       'EFRA1',
#                       'EFSF1',
#                       'EGHN7',
#                       'EINL1',
#                       'EKRC1',
#                       'ELZV2',
#                       'EMAT2',
#                       'EMDN7',
#                       'EMPL1',
#                       'EMWN7',
#                       'EPCM6',
#                       'EPPL1',
#                       'EPTT2',
#                       'EVRG1',
#                       'EWPN7',
#                       'EZMV2',
#                       'FBML1',
#                       'FCGT2',
#                       'FHBT2',
#                       'FIRN6',
#                       'FLXN6',
#                       'FMRF1',
#                       'FOXR1',
#                       'FPKG1',
#                       'FPST2',
#                       'FRDF1',
#                       'FRDW1',
#                       'FRHF1',
#                       'FRIN7',
#                       'FRPN6',
#                       'FRVM3',
#                       'FRWL1',
#                       'FSPL1',
#                       'FTMV2',
#                       'FTPC1',
#                       'FTPN3',
#                       'GBRM6',
#                       'GBSF1',
#                       'GCEF1',
#                       'GCYG1',
#                       'GIRM1',
#                       'GISL1',
#                       'GIST2',
#                       'GJCT2',
#                       'GLCM3',
#                       'GNDL1',
#                       'GNJT2',
#                       'GOOT2',
#                       'GPST2',
#                       'GRBW1',
#                       'GRPL1',
#                       'GRRT2',
#                       'GRWN4',
#                       'GSHA1',
#                       'GTND2',
#                       'GTOT2',
#                       'GULF1',
#                       'GVXC1',
#                       'HACN4',
#                       'HAGS1',
#                       'HAMO3',
#                       'HBKN7',
#                       'HBVT2',
#                       'HBYC1',
#                       'HCGN7',
#                       'HDGM2',
#                       'HLKN7',
#                       'HLNT2',
#                       'HMAL1',
#                       'HMNV2',
#                       'HOGN6',
#                       'HOLN7',
#                       'HOPT2',
#                       'HPGL1',
#                       'HPLF1',
#                       'HPMN3',
#                       'HSIT2',
#                       'HUMP4',
#                       'HUNM1',
#                       'HVRM3',
#                       'ICAC1',
#                       'IHDM2',
#                       'INRD1',
#                       'IRRD1',
#                       'IRWF1',
#                       'IWAL1',
#                       'IWDN6',
#                       'JAIW1',
#                       'JAKF1',
#                       'JCKN7',
#                       'JDWT2',
#                       'JMPN7',
#                       'JRAF1',
#                       'JSFV2',
#                       'JULF1',
#                       'KBTM1',
#                       'KIAS1',
#                       'KILL1',
#                       'KILN6',
#                       'KITN7',
#                       'KLNG1',
#                       'KLNM6',
#                       'KNBW1',
#                       'KPTN6',
#                       'KPTV2',
#                       'KRZL1',
#                       'KSBN4',
#                       'KYWF1',
#                       'LABL1',
#                       'LAPW1',
#                       'LCHL1',
#                       'LCRL1',
#                       'LCSL1',
#                       'LCVM1',
#                       'LEPL1',
#                       'LGCT2',
#                       'LHBT2',
#                       'LHNV2',
#                       'LJAC1',
#                       'LKHL1',
#                       'LKWF1',
#                       'LNDN6',
#                       'LOIP4',
#                       'LONV2',
#                       'LOPW1',
#                       'LPJC1',
#                       'LPQC1',
#                       'LRBV2',
#                       'LRLL1',
#                       'LTCV2',
#                       'LTQM2',
#                       'LUIT2',
#                       'LUQP4',
#                       'LVJT2',
#                       'LWSD1',
#                       'LWTV2',
#                       'LXRF1',
#                       'LYBT2',
#                       'LYMC3',
#                       'MAIN6',
#                       'MAUL1',
#                       'MBCL1',
#                       'MBET2',
#                       'MCGA1',
#                       'MCGL1',
#                       'MCSM1',
#                       'MERG1',
#                       'MEYC1',
#                       'MGPT2',
#                       'MGTN4',
#                       'MHBT2',
#                       'MIGM1',
#                       'MINN7',
#                       'MJBV2',
#                       'MLVL1',
#                       'MMAM1',
#                       'MNPV2',
#                       'MOBN6',
#                       'MOMH1',
#                       'MQTT2',
#                       'MRAL1',
#                       'MRCP1',
#                       'MRML1',
#                       'MRNF1',
#                       'MROS1',
#                       'MSBF1',
#                       'MSNN4',
#                       'MSVL1',
#                       'MTIP4',
#                       'MTKN6',
#                       'MTLN4',
#                       'MVRV2',
#                       'MYPF1',
#                       'MZXC1',
#                       'NAGN7',
#                       'NAPM6',
#                       'NATF1',
#                       'NBDM3',
#                       'NBLP1',
#                       'NBOP4',
#                       'NCHT2',
#                       'NCLL1',
#                       'NEAW1',
#                       'NIQS1',
#                       'NITS1',
#                       'NIXS1',
#                       'NLHC3',
#                       'NLRV2',
#                       'NLVL1',
#                       'NMCV2',
#                       'NMDV2',
#                       'NSBT2',
#                       'NSNS1',
#                       'NSWV2',
#                       'NTBC1',
#                       'NTKM3',
#                       'NTSN7',
#                       'NUET2',
#                       'NUTF1',
#                       'NWCL1',
#                       'NWHC3',
#                       'NWKN4',
#                       'NWPR1',
#                       'NYHC1',
#                       'OBCN7',
#                       'OBLA1',
#                       'OBRT2',
#                       'OCAN7',
#                       'OCIM2',
#                       'OMHC1',
#                       'ONCN4',
#                       'OPTF1',
#                       'ORIN6',
#                       'ORLN7',
#                       'ORNT2',
#                       'OTWN7',
#                       'PABN4',
#                       'PACF1',
#                       'PACT2',
#                       'PAGC1',
#                       'PALF1',
#                       'PAMN7',
#                       'PAUH1',
#                       'PCBF1',
#                       'PCGT2',
#                       'PCLF1',
#                       'PCML1',
#                       'PCNT2',
#                       'PCOC1',
#                       'PCUF1',
#                       'PDGS1',
#                       'PELF1',
#                       'PETM1',
#                       'PHBP1',
#                       'PHDP1',
#                       'PILL1',
#                       'PKMN6',
#                       'PLKM2',
#                       'PMAF1',
#                       'PMGT2',
#                       'PMTN6',
#                       'PNLM6',
#                       'PNPF1',
#                       'PNTL1',
#                       'POPM3',
#                       'PORO3',
#                       'PORT2',
#                       'PPTM1',
#                       'PPTM2',
#                       'PPZC1',
#                       'PRGF1',
#                       'PRIN6',
#                       'PRYC1',
#                       'PSBM1',
#                       'PSLC1',
#                       'PSTL1',
#                       'PTAW1',
#                       'PTFL1',
#                       'PTHM1',
#                       'PTRW1',
#                       'PTWW1',
#                       'PVHM3',
#                       'PWNG1',
#                       'QPTR1',
#                       'RBBT2',
#                       'RBDN7',
#                       'RCMC1',
#                       'RCPT2',
#                       'RCYF1',
#                       'RDYD1',
#                       'REYN6',
#                       'RGGT2',
#                       'RICV2',
#                       'RIOP4',
#                       'RIOT2',
#                       'RKLM1',
#                       'RKWN6',
#                       'RLIT2',
#                       'RLOT2',
#                       'RMLN7',
#                       'ROFN7',
#                       'ROQM1',
#                       'RPIP4',
#                       'RPLV2',
#                       'RRLL1',
#                       'RRVL1',
#                       'RSOW1',
#                       'RTAT2',
#                       'RTYC1',
#                       'RWYN6',
#                       'RYAC1',
#                       'RYBN6',
#                       'SABC3',
#                       'SADN6',
#                       'SAPF1',
#                       'SAQG1',
#                       'SAXV2',
#                       'SBEO3',
#                       'SBIF1',
#                       'SBIN4',
#                       'SBPT2',
#                       'SBTN4',
#                       'SBYT2',
#                       'SCPT2',
#                       'SDHN4',
#                       'SDRT2',
#                       'SEIM1',
#                       'SESM3',
#                       'SGCF1',
#                       'SGNT2',
#                       'SGSM2',
#                       'SHBL1',
#                       'SHBN4',
#                       'SHBW1',
#                       'SHIN6',
#                       'SHLT2',
#                       'SHNO3',
#                       'SHPF1',
#                       'SHPT2',
#                       'SICN4',
#                       'SISF1',
#                       'SJAN6',
#                       'SJLF1',
#                       'SJSN4',
#                       'SKAW1',
#                       'SKTF1',
#                       'SLIM2',
#                       'SLRF1',
#                       'SMML1',
#                       'SNAW1',
#                       'SNDN7',
#                       'SNSN7',
#                       'SOCS1',
#                       'SPTF1',
#                       'SPUF1',
#                       'SRPF1',
#                       'SRWG1',
#                       'SSNS1',
#                       'STDC3',
#                       'STFL1',
#                       'STHN7',
#                       'STIF1',
#                       'STKM1',
#                       'STUN7',
#                       'SUWF1',
#                       'SVDG1',
#                       'SWAN7',
#                       'SWBN7',
#                       'SWCL1',
#                       'SWMW1',
#                       'SWPV2',
#                       'SXHC1',
#                       'TANV2',
#                       'TAQT2',
#                       'TCBM2',
#                       'TCNW1',
#                       'TERN6',
#                       'TESL1',
#                       'TGBW1',
#                       'THAV2',
#                       'THLW1',
#                       'THOM1',
#                       'TKPN6',
#                       'TKTN4',
#                       'TLBO3',
#                       'TNHC1',
#                       'TOKW1',
#                       'TPBN4',
#                       'TRDF1',
#                       'TRJF1',
#                       'TWDL1',
#                       'TXPT2',
#                       'UCKN6',
#                       'ULAM6',
#                       'URHW1',
#                       'VAKF1',
#                       'VAPW1',
#                       'VCAT2',
#                       'VCPL1',
#                       'VNCL1',
#                       'VRIL1',
#                       'VTXC1',
#                       'WAHV2',
#                       'WASD2',
#                       'WATN4',
#                       'WAUO3',
#                       'WCHN7',
#                       'WCIF1',
#                       'WDPO3',
#                       'WELM1',
#                       'WESN6',
#                       'WESN7',
#                       'WFRA1',
#                       'WHLR1',
#                       'WIMD1',
#                       'WISM1',
#                       'WKQA1',
#                       'WLCL1',
#                       'WLON7',
#                       'WNAW1',
#                       'WNDV2',
#                       'WNGM3',
#                       'WPHL1',
#                       'WPIS1',
#                       'WPSL1',
#                       'WPTW1',
#                       'WRCS1',
#                       'WRIS1',
#                       'WRMH1',
#                       'WRVV2',
#                       'WYBS1',
#                       'WYCM6',
#                       'WYSS1',
#                       'YKTV2',
#                       'YPAW1',
#                       'ZBLC1',
#                       'ZCZC1',
#                       'ZDBC1',
#                       'ZDPC1',
#                       'ZGCC1',
#                       'ZMCC1',
#                       'ZMIC1',
#                       'ZOBC1',
#                       'ZOIC1',
#                       'ZPHC1',
#                       'ZPOC1',
#                       'ZPRC1',
#                       'ZSEC1',
#                       'ZSFC1']}

# %% [markdown]
# ### Total Water Level locations endpoint

# %% [markdown]
# Use this endpoint to locate total water level gauges and inspect their metadata:
#
# * **List All Gauges:** Fetch all National Weather Service (NWS) gauges  that have active total water level forecasts.
# * **Get Gauge Metadata:** Pass a specific NWS location id to retrieve its detailed metadata.

# %%
# create a locations request
uri = API_ENDPOINT + "/v1/total_water_level/locations"

print(f'Retrieving NWS gauges from {uri} ...')
# get the response
response = requests.request("GET", uri)
# print the response
pprint(response.json())  # print the first 10 NWM feature IDs)
# Out:
# Retrieving NWS gauges from https://api.staging.water.noaa.gov/nwm/v1/total_water_level/locations ...
# {'nws_location_ids': ['AAMC1',
#                       'ABOP4',
#                       'ABRW1',
#                       'ABSN4',
#                       'ACFS1',
#                       'ACYN4',
#                       'AGQC1',
#                       'ALBN6',
#                       'ALCN4',
#                       'ALIN7',
#                       'ALWH1',
#                       'AMEM3',
#                       'AMRL1',
#                       'ANAD2',
#                       'ANAH1',
#                       'ANPT2',
#                       'ANVC1',
#                       'APAM2',
#                       'APCF1',
#                       'AQCV2',
#                       'ARIW1',
#                       'ARRM1',
#                       'ASCN4',
#                       'ASPS1',
#                       'ASTF1',
#                       'ASTO3',
#                       'ATGM1',
#                       'ATLN4',
#                       'AVLN4',
#                       'AVNN7',
#                       'AVON7',
#                       'AWAC1',
#                       'AWRT2',
#                       'AXTV2',
#                       'AYCT2',
#                       'BAHM1',
#                       'BASN4',
#                       'BATN6',
#                       'BCSL1',
#                       'BCUF1',
#                       'BDAL1',
#                       'BDHV2',
#                       'BDPM2',
#                       'BDRN4',
#                       'BDSP1',
#                       'BDZC1',
#                       'BERN7',
#                       'BFBT2',
#                       'BFCS1',
#                       'BFTN7',
#                       'BGCV2',
#                       'BGLN4',
#                       'BGNN6',
#                       'BGYF1',
#                       'BHBM3',
#                       'BIDM1',
#                       'BISM2',
#                       'BKBF1',
#                       'BKNV2',
#                       'BKTL1',
#                       'BLDM2',
#                       'BLHN7',
#                       'BLIN7',
#                       'BLMN4',
#                       'BLRL1',
#                       'BLTM2',
#                       'BMTW1',
#                       'BOGN7',
#                       'BOWD1',
#                       'BPPD2',
#                       'BPPL1',
#                       'BQTM2',
#                       'BRHC3',
#                       'BRJF1',
#                       'BRND1',
#                       'BRNG1',
#                       'BRZT2',
#                       'BSRL1',
#                       'BSRN4',
#                       'BTBM1',
#                       'BTRL1',
#                       'BUCS1',
#                       'BVVN4',
#                       'BYSA1',
#                       'BZBM3',
#                       'BZST2',
#                       'CAMM1',
#                       'CAMM2',
#                       'CAPL1',
#                       'CAPN4',
#                       'CARL1',
#                       'CASM1',
#                       'CBBV2',
#                       'CBRN7',
#                       'CCHV2',
#                       'CCJF1',
#                       'CDDM1',
#                       'CECC1',
#                       'CFWM1',
#                       'CHAO3',
#                       'CHBM2',
#                       'CHBV2',
#                       'CHCM2',
#                       'CHDO3',
#                       'CHIV2',
#                       'CHMF1',
#                       'CHTM3',
#                       'CHTS1',
#                       'CHTT2',
#                       'CHWF1',
#                       'CHYW1',
#                       'CIBL1',
#                       'CIKA1',
#                       'CKBF1',
#                       'CKYF1',
#                       'CLCT2',
#                       'CLGN7',
#                       'CLIC3',
#                       'CLNM2',
#                       'CMAN4',
#                       'CNMF1',
#                       'COLN7',
#                       'COVM2',
#                       'CPCS1',
#                       'CPEM1',
#                       'CPFS1',
#                       'CPMV2',
#                       'CPNT2',
#                       'CPTM2',
#                       'CPTR1',
#                       'CPTT2',
#                       'CPTW1',
#                       'CRSM2',
#                       'CSAG1',
#                       'CTIN7',
#                       'CTMF1',
#                       'CTNP4',
#                       'CWBF1',
#                       'CWOL1',
#                       'CYTF1',
#                       'CZKF1',
#                       'DACL1',
#                       'DAMM1',
#                       'DCDF1',
#                       'DCWM1',
#                       'DELD1',
#                       'DGIF1',
#                       'DIBM6',
#                       'DICT2',
#                       'DILA1',
#                       'DKBN7',
#                       'DMSF1',
#                       'DNSF1',
#                       'DONL1',
#                       'DORP4',
#                       'DPBF1',
#                       'DPBO3',
#                       'DUCF1',
#                       'DUKN7',
#                       'DWMW1',
#                       'DYTT2',
#                       'EBEF1',
#                       'EBSW1',
#                       'EFRA1',
#                       'EFSF1',
#                       'EGHN7',
#                       'EINL1',
#                       'EKRC1',
#                       'ELZV2',
#                       'EMAT2',
#                       'EMDN7',
#                       'EMPL1',
#                       'EMWN7',
#                       'EPCM6',
#                       'EPPL1',
#                       'EPTT2',
#                       'EVRG1',
#                       'EWPN7',
#                       'EZMV2',
#                       'FBML1',
#                       'FCGT2',
#                       'FESN7',
#                       'FHBT2',
#                       'FIRN6',
#                       'FLXN6',
#                       'FMRF1',
#                       'FOXR1',
#                       'FPKG1',
#                       'FPST2',
#                       'FRDF1',
#                       'FRDW1',
#                       'FRHF1',
#                       'FRIN7',
#                       'FRPN6',
#                       'FRVM3',
#                       'FRWL1',
#                       'FSPL1',
#                       'FTMV2',
#                       'FTPC1',
#                       'FTPN3',
#                       'GBRM6',
#                       'GBSF1',
#                       'GCEF1',
#                       'GCYG1',
#                       'GIRM1',
#                       'GISL1',
#                       'GIST2',
#                       'GJCT2',
#                       'GLCM3',
#                       'GNDL1',
#                       'GNJT2',
#                       'GOOT2',
#                       'GPST2',
#                       'GRBW1',
#                       'GRMN7',
#                       'GRPL1',
#                       'GRRT2',
#                       'GRWN4',
#                       'GSHA1',
#                       'GTND2',
#                       'GTOT2',
#                       'GULF1',
#                       'GVXC1',
#                       'HACN4',
#                       'HAGS1',
#                       'HAMO3',
#                       'HBKN7',
#                       'HBVT2',
#                       'HBYC1',
#                       'HCGN7',
#                       'HDGM2',
#                       'HLKN7',
#                       'HLNT2',
#                       'HMAL1',
#                       'HMNV2',
#                       'HOGN6',
#                       'HOLN7',
#                       'HOPT2',
#                       'HPGL1',
#                       'HPLF1',
#                       'HPMN3',
#                       'HSIT2',
#                       'HUMP4',
#                       'HUNM1',
#                       'HVRM3',
#                       'ICAC1',
#                       'IHDM2',
#                       'INRD1',
#                       'IRRD1',
#                       'IRWF1',
#                       'IWAL1',
#                       'IWDN6',
#                       'JAIW1',
#                       'JAKF1',
#                       'JCKN7',
#                       'JDWT2',
#                       'JMPN7',
#                       'JRAF1',
#                       'JSFV2',
#                       'JULF1',
#                       'KBTM1',
#                       'KIAS1',
#                       'KILL1',
#                       'KILN6',
#                       'KITN7',
#                       'KLNG1',
#                       'KLNM6',
#                       'KNBW1',
#                       'KPTN6',
#                       'KPTV2',
#                       'KRZL1',
#                       'KSBN4',
#                       'KYWF1',
#                       'LABL1',
#                       'LAPW1',
#                       'LCHL1',
#                       'LCLL1',
#                       'LCRL1',
#                       'LCSL1',
#                       'LCVM1',
#                       'LEPL1',
#                       'LGCT2',
#                       'LHBT2',
#                       'LHNV2',
#                       'LJAC1',
#                       'LKHL1',
#                       'LKWF1',
#                       'LNDN6',
#                       'LOIP4',
#                       'LONV2',
#                       'LOPW1',
#                       'LPJC1',
#                       'LPQC1',
#                       'LRBV2',
#                       'LRLL1',
#                       'LSPV2',
#                       'LTCV2',
#                       'LTQM2',
#                       'LUIT2',
#                       'LUQP4',
#                       'LVJT2',
#                       'LWSD1',
#                       'LWTV2',
#                       'LXRF1',
#                       'LYBT2',
#                       'LYMC3',
#                       'MAIN6',
#                       'MAUL1',
#                       'MBCL1',
#                       'MBET2',
#                       'MCGA1',
#                       'MCGL1',
#                       'MCSM1',
#                       'MERG1',
#                       'MEYC1',
#                       'MGPT2',
#                       'MGTN4',
#                       'MHBT2',
#                       'MIGM1',
#                       'MINN7',
#                       'MJBV2',
#                       'MLVL1',
#                       'MMAM1',
#                       'MNPV2',
#                       'MOBN6',
#                       'MOMH1',
#                       'MQTT2',
#                       'MRAL1',
#                       'MRCP1',
#                       'MRML1',
#                       'MRNF1',
#                       'MROS1',
#                       'MSBF1',
#                       'MSNN4',
#                       'MSVL1',
#                       'MTIP4',
#                       'MTKN6',
#                       'MTLN4',
#                       'MVRV2',
#                       'MYPF1',
#                       'MZXC1',
#                       'NAGN7',
#                       'NAPM6',
#                       'NATF1',
#                       'NBDM3',
#                       'NBLP1',
#                       'NBOP4',
#                       'NCDV2',
#                       'NCHT2',
#                       'NCLL1',
#                       'NEAW1',
#                       'NIQS1',
#                       'NITS1',
#                       'NIXS1',
#                       'NLHC3',
#                       'NLRV2',
#                       'NLVL1',
#                       'NMCV2',
#                       'NMDV2',
#                       'NPSF1',
#                       'NSBT2',
#                       'NSNS1',
#                       'NSWV2',
#                       'NTBC1',
#                       'NTKM3',
#                       'NTSN7',
#                       'NUET2',
#                       'NUTF1',
#                       'NWCL1',
#                       'NWHC3',
#                       'NWKN4',
#                       'NWPR1',
#                       'NYHC1',
#                       'OBCN7',
#                       'OBLA1',
#                       'OBRT2',
#                       'OCAN7',
#                       'OCIM2',
#                       'OHBC1',
#                       'OMHC1',
#                       'ONCN4',
#                       'OPTF1',
#                       'ORIN6',
#                       'ORIN7',
#                       'ORLN7',
#                       'ORNT2',
#                       'OTWN7',
#                       'PABN4',
#                       'PACF1',
#                       'PACT2',
#                       'PAGC1',
#                       'PALF1',
#                       'PAMN7',
#                       'PAUH1',
#                       'PCBF1',
#                       'PCGT2',
#                       'PCLF1',
#                       'PCML1',
#                       'PCNT2',
#                       'PCOC1',
#                       'PCRL1',
#                       'PCUF1',
#                       'PDGS1',
#                       'PELF1',
#                       'PETM1',
#                       'PHBP1',
#                       'PHDP1',
#                       'PILL1',
#                       'PKMN6',
#                       'PLKM2',
#                       'PMAF1',
#                       'PMGT2',
#                       'PMTN6',
#                       'PNLM6',
#                       'PNPF1',
#                       'PNTL1',
#                       'POPM3',
#                       'PORO3',
#                       'PORT2',
#                       'PPTM1',
#                       'PPTM2',
#                       'PPZC1',
#                       'PRGF1',
#                       'PRIN6',
#                       'PRYC1',
#                       'PSBM1',
#                       'PSLC1',
#                       'PSTL1',
#                       'PTAW1',
#                       'PTFL1',
#                       'PTHM1',
#                       'PTIT2',
#                       'PTRW1',
#                       'PTWW1',
#                       'PULM1',
#                       'PVHM3',
#                       'PWNG1',
#                       'QPTR1',
#                       'QTGV2',
#                       'RBBT2',
#                       'RBDN7',
#                       'RCMC1',
#                       'RCPT2',
#                       'RCYF1',
#                       'RDYD1',
#                       'REYN6',
#                       'RGGT2',
#                       'RICV2',
#                       'RIOP4',
#                       'RIOT2',
#                       'RKLM1',
#                       'RKWN6',
#                       'RLIT2',
#                       'RLOT2',
#                       'RMLN7',
#                       'ROFN7',
#                       'ROQM1',
#                       'RPIP4',
#                       'RPLV2',
#                       'RRLL1',
#                       'RRVL1',
#                       'RSOW1',
#                       'RTAT2',
#                       'RTYC1',
#                       'RWYN6',
#                       'RYAC1',
#                       'RYBN6',
#                       'SABC3',
#                       'SADN6',
#                       'SAPF1',
#                       'SAQG1',
#                       'SAXV2',
#                       'SAYN6',
#                       'SBEO3',
#                       'SBIF1',
#                       'SBIN4',
#                       'SBPT2',
#                       'SBTN4',
#                       'SBYT2',
#                       'SCPT2',
#                       'SCTM3',
#                       'SDBC1',
#                       'SDHN4',
#                       'SDRT2',
#                       'SEIM1',
#                       'SESM3',
#                       'SGCF1',
#                       'SGNT2',
#                       'SGSM2',
#                       'SHBL1',
#                       'SHBN4',
#                       'SHBW1',
#                       'SHIN6',
#                       'SHLT2',
#                       'SHNO3',
#                       'SHPF1',
#                       'SHPT2',
#                       'SICN4',
#                       'SISF1',
#                       'SJAN6',
#                       'SJLF1',
#                       'SJSN4',
#                       'SKAW1',
#                       'SKTF1',
#                       'SLIM2',
#                       'SLRF1',
#                       'SMML1',
#                       'SNAW1',
#                       'SNDN7',
#                       'SNSN7',
#                       'SOCS1',
#                       'SPTF1',
#                       'SPUF1',
#                       'SRPF1',
#                       'SRWG1',
#                       'SSNS1',
#                       'STDC3',
#                       'STFL1',
#                       'STHN7',
#                       'STIF1',
#                       'STKM1',
#                       'STUN7',
#                       'SUWF1',
#                       'SVDG1',
#                       'SWAN7',
#                       'SWBN7',
#                       'SWCL1',
#                       'SWMW1',
#                       'SWPV2',
#                       'SXHC1',
#                       'TANV2',
#                       'TAQT2',
#                       'TCBM2',
#                       'TCNW1',
#                       'TERN6',
#                       'TESL1',
#                       'TGBW1',
#                       'THAV2',
#                       'THLW1',
#                       'THOM1',
#                       'TKPN6',
#                       'TKTN4',
#                       'TLBO3',
#                       'TNHC1',
#                       'TOKW1',
#                       'TPBN4',
#                       'TRDF1',
#                       'TRJF1',
#                       'TWDL1',
#                       'TXPT2',
#                       'UCKN6',
#                       'ULAM6',
#                       'URHW1',
#                       'VAKF1',
#                       'VAPW1',
#                       'VCAF1',
#                       'VCAT2',
#                       'VCPL1',
#                       'VNCL1',
#                       'VRIL1',
#                       'VTXC1',
#                       'WAHV2',
#                       'WASD2',
#                       'WATN4',
#                       'WAUO3',
#                       'WCHN7',
#                       'WCIF1',
#                       'WDPO3',
#                       'WELM1',
#                       'WESN6',
#                       'WESN7',
#                       'WFRA1',
#                       'WHLR1',
#                       'WIMD1',
#                       'WISM1',
#                       'WKQA1',
#                       'WLCL1',
#                       'WLON7',
#                       'WNAW1',
#                       'WNDV2',
#                       'WNGM3',
#                       'WPHL1',
#                       'WPIS1',
#                       'WPSL1',
#                       'WPTW1',
#                       'WRCS1',
#                       'WRIS1',
#                       'WRMH1',
#                       'WRVV2',
#                       'WYBS1',
#                       'WYCM6',
#                       'WYSS1',
#                       'YKTV2',
#                       'YPAW1',
#                       'ZBLC1',
#                       'ZCZC1',
#                       'ZDBC1',
#                       'ZDPC1',
#                       'ZGCC1',
#                       'ZMCC1',
#                       'ZMIC1',
#                       'ZOBC1',
#                       'ZOIC1',
#                       'ZPHC1',
#                       'ZPOC1',
#                       'ZPRC1',
#                       'ZSEC1',
#                       'ZSFC1']}

# %%
# create a locations metadata request
uri = API_ENDPOINT + "/v1/total_water_level/locations/THOM1"
# get the response
response = requests.request("GET", uri)
# print the response
pprint(response.json())
# Out:
# {'domain': 'ATL', 'nws_location_id': 'THOM1'}

# %% [markdown]
# ---
# ## Summary & Key Takeaways
#
# In this notebook, we explored how to interact with the National Water Model (NWM) API to discover and retrieve metadata data for NWS gauges.
#
# **Key Takeaways:**
# * **Configuration Discovery:** Queried available NWM forecast configurations to identify active model runs.
# * **Reach Identification & Metadata:** Filtered and retrieved total water level gauges along with their associated spatial and hydrological attributes.
# * **API Flexibility:** Learned general techniques for querying endpoints, applying filters, and inspecting metadata across any resource in the NWM API.
